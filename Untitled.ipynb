# %%
import requests
import pandas as pd
import json

# %%
game = requests.get("http://statsapi.mlb.com//api/v1/game/529569/feed/live")
game = str(game.content)
game
# Out:
# 'b\'{"metaData":{"timeStamp":"20190124_082521","wait":"10","logicalEvents":[],"dfeEvents":[]},"copyright":"Copyright 2019 MLB Advanced Media, L.P.  Use of any content on this page acknowledges agreement to the terms posted here http://gdx.mlb.com/components/copyright.txt","gameData":{"alerts":[],"venue":{"channelLoc":"USCA0638","name":"Dodger Stadium","location":"Los Angeles, CA","id":"22"},"game":{"doubleHeader":"N","calendarEventID":"14-529569-2018-04-10","gameNumber":"1","season":"2018.0","pk":"529569","id":"2018_04_10_oakmlb_lanmlb_1","tiebreaker":"N","type":"R","gamedayType":"P","seasonDisplay":"2018"},"datetime":{"away":{"ampm":"PM","league":{"ampm":"PM","timeZoneGen":"ET","timeZone":"-4","time":"10:10","timeDate":"2018/04/10 10:10"},"timeZone":"PT","time":"7:10"},"ampm":"PM","dayNight":"night","originalDate":"2018/04/10","timeZone":"ET","time":"10:10","day":"TUE","timeDate":"2018/04/10 10:10","firstPitchET":"","resumeDate":null,"timeGMT":null,"home":{"ampm":"PM","league":{"amp
# ...

# %%
print(json.dumps(game, sort_keys=False, indent=4))
# Out:
# "b'{\"metaData\":{\"timeStamp\":\"20190124_082521\",\"wait\":\"10\",\"logicalEvents\":[],\"dfeEvents\":[]},\"copyright\":\"Copyright 2019 MLB Advanced Media, L.P.  Use of any content on this page acknowledges agreement to the terms posted here http://gdx.mlb.com/components/copyright.txt\",\"gameData\":{\"alerts\":[],\"venue\":{\"channelLoc\":\"USCA0638\",\"name\":\"Dodger Stadium\",\"location\":\"Los Angeles, CA\",\"id\":\"22\"},\"game\":{\"doubleHeader\":\"N\",\"calendarEventID\":\"14-529569-2018-04-10\",\"gameNumber\":\"1\",\"season\":\"2018.0\",\"pk\":\"529569\",\"id\":\"2018_04_10_oakmlb_lanmlb_1\",\"tiebreaker\":\"N\",\"type\":\"R\",\"gamedayType\":\"P\",\"seasonDisplay\":\"2018\"},\"datetime\":{\"away\":{\"ampm\":\"PM\",\"league\":{\"ampm\":\"PM\",\"timeZoneGen\":\"ET\",\"timeZone\":\"-4\",\"time\":\"10:10\",\"timeDate\":\"2018/04/10 10:10\"},\"timeZone\":\"PT\",\"time\":\"7:10\"},\"ampm\":\"PM\",\"dayNight\":\"night\",\"originalDate\":\"2018/04/10\",\"timeZone\":\"ET\",\"time\
# ...

# %%
with open('data.json', 'w') as fp:
    json.dump(game, fp)

# %%
df = pd.read_json('data.json')
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-8deb8813ba70> in <module>
# ----> 1 df = pd.read_json('data.json')
#       2 df
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     212                 else:
#     213                     kwargs[new_arg_name] = new_arg_value
# --> 214             return func(*args, **kwargs)
#     215
#     216         return cast(F, wrapper)
#
# ~\anaconda3\lib\site-packages\pandas\io\json\_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     606         return json_reader
#     607
# --> 608     result = json_reader.read()
#     609     if should_close:
#     610         filepath_or_buffer.close()
#
# ...
